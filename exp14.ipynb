# %% [markdown]
# <a href="https://colab.research.google.com/github/Mysterio-maker/EXPERIMENT-14/blob/main/exp14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Experiment-14
#
# ####Data Normalization and Data Type Conversion
#
# ### Name: Amey Waghmare
# ### Prn:25070123009
# ### Batch:A1

# %% [markdown]
# PART A - Data Normalization

# %%
import pandas as pd
import numpy as np
data={
    'Product':['Laptop','Mobile','Tablet','Headphones','Smartwatch','Camera'],
    'Price':[55000,20000,30000,2000,8000,45000],
    'Units_sold':[25,60,35,80,50,15],
    'Discount':[10,15,12,20,18,8]
}

df = pd.DataFrame(data)

print("Original Dataset")
print(df)
# Out:
# Original Dataset
#       Product  Price  Units_sold  Discount
# 0      Laptop  55000          25        10
# 1      Mobile  20000          60        15
# 2      Tablet  30000          35        12
# 3  Headphones   2000          80        20
# 4  Smartwatch   8000          50        18
# 5      Camera  45000          15         8

# %%
#1.Min-Max Normalization
df['Price_MinMax']=(df['Price']-df['Price'].min())/(df['Price'].max()-df['Price'].min())

print("\nMin-Max Normalized Price")
print(df[['Product','Price','Price_MinMax']])
# Out:
# Min-Max Normalized Price
#       Product  Price  Price_MinMax
# 0      Laptop  55000      1.000000
# 1      Mobile  20000      0.339623
# 2      Tablet  30000      0.528302
# 3  Headphones   2000      0.000000
# 4  Smartwatch   8000      0.113208
# 5      Camera  45000      0.811321

# %%
#1.Units_sold_MinMax Normalization
df['Units_sold_MinMax']=(df['Units_sold']-df['Units_sold'].min())/(df['Units_sold'].max()-df['Units_sold'].min())

print("\nMin-Max Normalized Units_sold")
print(df[['Product','Units_sold','Units_sold_MinMax']])
# Out:
# Min-Max Normalized Units_sold
#       Product  Units_sold  Units_sold_MinMax
# 0      Laptop          25           0.153846
# 1      Mobile          60           0.692308
# 2      Tablet          35           0.307692
# 3  Headphones          80           1.000000
# 4  Smartwatch          50           0.538462
# 5      Camera          15           0.000000

# %%
#1.Discount_Min-Max Normalization
df['Discount_MinMax']=(df['Discount']-df['Discount'].min())/(df['Discount'].max()-df['Discount'].min())

print("\nMin-Max Normalized Discount")
print(df[['Product','Discount','Discount_MinMax']])
# Out:
# Min-Max Normalized Discount
#       Product  Discount  Discount_MinMax
# 0      Laptop        10         0.166667
# 1      Mobile        15         0.583333
# 2      Tablet        12         0.333333
# 3  Headphones        20         1.000000
# 4  Smartwatch        18         0.833333
# 5      Camera         8         0.000000

# %%
#2.Z-score Normalization
df['Units_Zscore']= (df['Units_sold']-df['Units_sold'].mean()) / df['Units_sold'].std()

print("\nZ-score Normalized Units sold")
print(df[['Product','Units_sold','Units_Zscore']])
# Out:
# Z-score Normalized Units sold
#       Product  Units_sold  Units_Zscore
# 0      Laptop          25     -0.799885
# 1      Mobile          60      0.660775
# 2      Tablet          35     -0.382554
# 3  Headphones          80      1.495437
# 4  Smartwatch          50      0.243443
# 5      Camera          15     -1.217216

# %%
#3.Decimal Scaling
df['Price_Decimal'] = df['Price']/100000

print("\ndecimal Scaling")
print(df[['Product','Price','Price_Decimal']])
# Out:
# decimal Scaling
#       Product  Price  Price_Decimal
# 0      Laptop  55000           0.55
# 1      Mobile  20000           0.20
# 2      Tablet  30000           0.30
# 3  Headphones   2000           0.02
# 4  Smartwatch   8000           0.08
# 5      Camera  45000           0.45

# %%
#3.Decimal Scaling
df['Discount_Decimal'] = df['Discount']/100

print("\ndecimal Scaling")
print(df[['Product','Discount','Discount_Decimal']])
# Out:
# decimal Scaling
#       Product  Discount  Discount_Decimal
# 0      Laptop        10              0.10
# 1      Mobile        15              0.15
# 2      Tablet        12              0.12
# 3  Headphones        20              0.20
# 4  Smartwatch        18              0.18
# 5      Camera         8              0.08

# %%
#Normalize Multiple Columns
cols = ['Price','Units_sold','Discount']

df_norm =(df[cols] - df[cols].min())/(df[cols].max() - df[cols].max())

print("\nNormalized Dataset")
print(df_norm)
# Out:
# Normalized Dataset
#    Price  Units_sold  Discount
# 0    inf         inf       inf
# 1    inf         inf       inf
# 2    inf         inf       inf
# 3    NaN         inf       inf
# 4    inf         inf       inf
# 5    inf         NaN       NaN

# %% [markdown]
# PART B-Data Type Conversion

# %%
data = {
    'Order_ID':[101,102,103,104,105,106],
    'Customer_Gender':['Male','Female','Female','Male','Female','Male'],
    'Product_Method':['UPI','Credit Card','Debit Card','COD','UPI','Debit Card'],
    'Product_Category':['Electronics','Clothing','Home','Electronics','Beauty','Electrolnics'],
    'City':['Pune','Mumbai','Delhi','Bangalore','Pune','Hyderabad'],
    'Order_Value':[4500,2300,3200,5200,1800,4100]

}

df = pd.DataFrame(data)

print(df)
# Out:
#    Order_ID Customer_Gender Product_Method Product_Category       City  \
# 0       101            Male            UPI      Electronics       Pune
# 1       102          Female    Credit Card         Clothing     Mumbai
# 2       103          Female     Debit Card             Home      Delhi
# 3       104            Male            COD      Electronics  Bangalore
# 4       105          Female            UPI           Beauty       Pune
# 5       106            Male     Debit Card     Electrolnics  Hyderabad
#
#    Order_Value
# 0         4500
# 1         2300
# 2         3200
# 3         5200
# 4         1800
# 5         4100

# %%
#Method 1: Label Encoding
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['Gender_Label'] = le.fit_transform(df['Customer_Gender'])

df
# Out:
#    Order_ID Customer_Gender Product_Method Product_Category       City  \
# 0       101            Male            UPI      Electronics       Pune
# 1       102          Female    Credit Card         Clothing     Mumbai
# 2       103          Female     Debit Card             Home      Delhi
# 3       104            Male            COD      Electronics  Bangalore
# 4       105          Female            UPI           Beauty       Pune
# 5       106            Male     Debit Card     Electrolnics  Hyderabad
#
#    Order_Value  Gender_Label
# 0         4500             1
# 1         2300             0
# 2         3200             0
# 3         5200             1
# 4         1800             0
# 5         4100             1

# %%
#Method 2: One-Hot Encoding
df_encoded = pd.get_dummies(df,columns=['Product_Method'])

df_encoded
# Out:
#    Order_ID Customer_Gender Product_Category       City  Order_Value  \
# 0       101            Male      Electronics       Pune         4500
# 1       102          Female         Clothing     Mumbai         2300
# 2       103          Female             Home      Delhi         3200
# 3       104            Male      Electronics  Bangalore         5200
# 4       105          Female           Beauty       Pune         1800
# 5       106            Male     Electrolnics  Hyderabad         4100
#
#    Gender_Label  Product_Method_COD  Product_Method_Credit Card  \
# 0             1               False                       False
# 1             0               False                        True
# 2             0               False                       False
# 3             1                True                       False
# 4             0               False                       False
# 5             1               False                       False
#
#    Product_Method_Debit Card  Product_Method_UPI
# 0                      False                True
# 1                      False               False
# 2                       True               False
# 3                      False               False
# 4                      False                True
# 5                       True               False

# %%
#Method 3: Encoding Multiple Columns
df_multi = pd.get_dummies(df,columns=['Product_Category','City'])

df_multi
# Out:
#    Order_ID Customer_Gender Product_Method  Order_Value  Gender_Label  \
# 0       101            Male            UPI         4500             1
# 1       102          Female    Credit Card         2300             0
# 2       103          Female     Debit Card         3200             0
# 3       104            Male            COD         5200             1
# 4       105          Female            UPI         1800             0
# 5       106            Male     Debit Card         4100             1
#
#    Product_Category_Beauty  Product_Category_Clothing  \
# 0                    False                      False
# 1                    False                       True
# 2                    False                      False
# 3                    False                      False
# 4                     True                      False
# 5                    False                      False
#
#    Product_Category_Electrolnics  Product_Category_Electronics  \
# 0                          False                          True
# 1                          False                         False
# 2                          False                         False
# 3                          False                          True
# 4                          False                         False
# 5                           True                         False
#
#    Product_Category_Home  City_Bangalore  City_Delhi  City_Hyderabad  \
# 0                  False           False       False           False
# 1                  False           False       False           False
# 2                   True           False        True           False
# 3                  False            True       False           False
# 4                  False           False       False           False
# 5                  False           False       False            True
#
#    City_Mumbai  City_Pune
# 0        False       True
# 1         True      False
# 2        False      False
# 3        False      False
# 4        False       True
# 5        False      False

# %%
#Method 4: Dummy Encoding (Drop First)
df_dummy = pd.get_dummies(df,columns=['Product_Method'],drop_first=True)

df_dummy
# Out:
#    Order_ID Customer_Gender Product_Category       City  Order_Value  \
# 0       101            Male      Electronics       Pune         4500
# 1       102          Female         Clothing     Mumbai         2300
# 2       103          Female             Home      Delhi         3200
# 3       104            Male      Electronics  Bangalore         5200
# 4       105          Female           Beauty       Pune         1800
# 5       106            Male     Electrolnics  Hyderabad         4100
#
#    Gender_Label  Product_Method_Credit Card  Product_Method_Debit Card  \
# 0             1                       False                      False
# 1             0                        True                      False
# 2             0                       False                       True
# 3             1                       False                      False
# 4             0                       False                      False
# 5             1                       False                       True
#
#    Product_Method_UPI
# 0                True
# 1               False
# 2               False
# 3               False
# 4                True
# 5               False

# %% [markdown]
# NEW DATASET OPERATIONS

# %%
#Data Normalization
import pandas as pd
df = pd.read_csv("/content/amazon_products_dataset_Expt-14.csv")

# %%
df
# Out:
#    Product_ID                 Product_Name  Price  Rating  Reviews  Units_Sold
# 0        P101               Wireless Mouse    799     4.3     1520         350
# 1        P102            Bluetooth Speaker   1499     4.5      980         220
# 2        P103                 USB Keyboard    699     4.1      870         180
# 3        P104               Gaming Headset   2499     4.6     2100         410
# 4        P105                   Smartwatch   3999     4.4     3050         520
# 5        P106                   Power Bank   1199     4.2     1750         390
# 6        P107                 Laptop Stand    899     4.0      620         140
# 7        P108                       Webcam   1899     4.3     1120         260
# 8        P109                 Portable SSD   5499     4.7     1850         330
# 9        P110             Wireless Charger    999     4.2      760         190
# 10       P111  Noise Cancelling Headphones   7999     4.6     4200         610
# 11       P112          Mechanical Keyboard   4599     4.5     2100         290
# 12       P113                 Gaming Mouse   1599     4.4     1300         340
# 13       P114                 Tablet Stand    699     4.1      540         120
# 14       P115                      USB Hub    899     4.2      870         200
# 15       P116          External Hard Drive   6499     4.6     2300         310
# 16       P117            Smartphone Tripod   1199     4.3      760         210
# 17       P118              Laptop Backpack   1999     4.4     1600         420
# 32 -0.172428  0.092542  1.261039    1.472674
# 33  1.463325  1.120787 -0.008707   -1.086345
# 34  2.233090  1.634910  0.777327   -1.333992
# 35 -0.730508 -1.449825 -1.217989   -0.756149
# 36 -0.692019 -0.935703 -0.673812    0.564635
# 37 -0.788240 -1.963948 -1.036597    1.059929
# 38 -0.653531 -0.421580 -0.891483   -0.343404
# 39 -0.557310  0.092542 -1.133339   -1.003796
# 40 -0.268648  0.606665 -0.734276   -0.838698
# 41  1.270883  1.120787 -0.311027   -1.168894
# 42  0.116235  0.092542  0.777327    0.069341
# 43  3.965063  1.634910  0.414542   -1.499090
# 44 -0.461090 -0.421580 -0.069171    0.482086
# 45  0.693559  1.120787  0.898255   -0.425953
# 46  2.810415  0.606665  0.233150   -1.086345
# 47 -0.364869  0.092542 -0.577069   -0.673600
# 48 -0.172428 -0.421580 -0.710090   -0.838698
# 49 -0.653531 -0.935703 -0.843111   -0.095757

# %%
#cols = ['Price','Units_Sold','Reviews','Rating']
#3.Decimal Scaling
df['Price_Decimal'] = df['Price']/100

print("\ndecimal Scaling")
print(df[['Price','Price_Decimal']])
# Out:
# decimal Scaling
#     Price  Price_Decimal
# 0     799           7.99
# 1    1499          14.99
# 2     699           6.99
# 3    2499          24.99
# 4    3999          39.99
# 5    1199          11.99
# 6     899           8.99
# 7    1899          18.99
# 8    5499          54.99
# 9     999           9.99
# 10   7999          79.99
# 11   4599          45.99
# 12   1599          15.99
# 13    699           6.99
# 14    899           8.99
# 15   6499          64.99
# 16   1199          11.99
# 17   1999          19.99
# 18   2999          29.99
# 19   1299          12.99
# 20    499           4.99
# 21   2499          24.99
# 22   8999          89.99
# 23    799           7.99
# 24   3499          34.99
# 25   4599          45.99
# 26  12999         129.99
# 27   2199          21.99
# 28    699           6.99
# 29   1499          14.99
# 30   9999          99.99
# 31   5999          59.99
# 32   3499          34.99
# 33  11999         119.99
# 34  15999         159.99
# 35    599           5.99
# 36    799           7.99
# 37    299           2.99
# 38    999           9.99
# 39   1499          14.99
# 40   2999          29.99
# 41  10999         109.99
# 42   4999          49.99
# 43  24999         249.99
# 44   1999          19.99
# 45   7999          79.99
# 46  18999         189.99
# 47   2499          24.99
# 48   3499          34.99
# 49    999           9.99

# %%
#Data conversion
import pandas as pd
df = pd.read_csv("/content/Student-Dataset.csv")

# %%
df
# Out:
#    Roll_No  Gender  Department  CGPA  Number_of_Backlogs  \
# 0      101  Female    Computer   8.2                   0
# 1      102    Male          IT   7.5                   1
# 2      103  Female        ENTC   9.1                   0
# 3      104    Male  Mechanical   6.8                   2
# 4      105  Female    Computer   8.7                   0
# 5      106    Male       Civil   7.2                   3
# 6      107  Female          IT   8.9                   0
# 7      108    Male    Computer   6.5                   1
# 8      109  Female        ENTC   7.8                   0
# 9      110    Male  Mechanical   7.0                   2
#
#    Attendance_Percentage Placement_Status  Salary
# 0                     92           Placed  450000
# 1                     85       Not Placed       0
# 2                     96           Placed  550000
# 3                     78       Not Placed       0
# 4                     88           Placed  480000
# 5                     72       Not Placed       0
# 6                     91           Placed  500000
# 7                     80       Not Placed       0
# 8                     84           Placed  420000
# 9                     76       Not Placed       0

# %%
#Method 1: Label Encoding
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['Placement_Status'] = le.fit_transform(df['Gender'])

df
# Out:
#    Roll_No  Gender  Department  CGPA  Number_of_Backlogs  \
# 0      101  Female    Computer   8.2                   0
# 1      102    Male          IT   7.5                   1
# 2      103  Female        ENTC   9.1                   0
# 3      104    Male  Mechanical   6.8                   2
# 4      105  Female    Computer   8.7                   0
# 5      106    Male       Civil   7.2                   3
# 6      107  Female          IT   8.9                   0
# 7      108    Male    Computer   6.5                   1
# 8      109  Female        ENTC   7.8                   0
# 9      110    Male  Mechanical   7.0                   2
#
#    Attendance_Percentage  Placement_Status  Salary
# 0                     92                 0  450000
# 1                     85                 1       0
# 2                     96                 0  550000
# 3                     78                 1       0
# 4                     88                 0  480000
# 5                     72                 1       0
# 6                     91                 0  500000
# 7                     80                 1       0
# 8                     84                 0  420000
# 9                     76                 1       0

# %%
#OHC-Department
df_encoded = pd.get_dummies(df,columns=['Department'])

df_encoded
# Out:
#    Roll_No  Gender  CGPA  Number_of_Backlogs  Attendance_Percentage  \
# 0      101  Female   8.2                   0                     92
# 1      102    Male   7.5                   1                     85
# 2      103  Female   9.1                   0                     96
# 3      104    Male   6.8                   2                     78
# 4      105  Female   8.7                   0                     88
# 5      106    Male   7.2                   3                     72
# 6      107  Female   8.9                   0                     91
# 7      108    Male   6.5                   1                     80
# 8      109  Female   7.8                   0                     84
# 9      110    Male   7.0                   2                     76
#
#    Placement_Status  Salary  Department_Civil  Department_Computer  \
# 0                 0  450000             False                 True
# 1                 1       0             False                False
# 2                 0  550000             False                False
# 3                 1       0             False                False
# 4                 0  480000             False                 True
# 5                 1       0              True                False
# 6                 0  500000             False                False
# 7                 1       0             False                 True
# 8                 0  420000             False                False
# 9                 1       0             False                False
#
#    Department_ENTC  Department_IT  Department_Mechanical
# 0            False          False                  False
# 1            False           True                  False
# 2             True          False                  False
# 3            False          False                   True
# 4            False          False                  False
# 5            False          False                  False
# 6            False           True                  False
# 7            False          False                  False
# 8             True          False                  False
# 9            False          False                   True

# %%
#Dummies-Department
df_encoded = pd.get_dummies(df,columns=['Department'])

df_encoded
# Out:
#    Roll_No  Gender  CGPA  Number_of_Backlogs  Attendance_Percentage  \
# 0      101  Female   8.2                   0                     92
# 1      102    Male   7.5                   1                     85
# 2      103  Female   9.1                   0                     96
# 3      104    Male   6.8                   2                     78
# 4      105  Female   8.7                   0                     88
# 5      106    Male   7.2                   3                     72
# 6      107  Female   8.9                   0                     91
# 7      108    Male   6.5                   1                     80
# 8      109  Female   7.8                   0                     84
# 9      110    Male   7.0                   2                     76
#
#    Placement_Status  Salary  Department_Civil  Department_Computer  \
# 0                 0  450000             False                 True
# 1                 1       0             False                False
# 2                 0  550000             False                False
# 3                 1       0             False                False
# 4                 0  480000             False                 True
# 5                 1       0              True                False
# 6                 0  500000             False                False
# 7                 1       0             False                 True
# 8                 0  420000             False                False
# 9                 1       0             False                False
#
#    Department_ENTC  Department_IT  Department_Mechanical
# 0            False          False                  False
# 1            False           True                  False
# 2             True          False                  False
# 3            False          False                   True
# 4            False          False                  False
# 5            False          False                  False
# 6            False           True                  False
# 7            False          False                  False
# 8             True          False                  False
# 9            False          False                   True
